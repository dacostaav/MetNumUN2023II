# %% [markdown]
# **Last digits: 1-4-9**
#
# 1 Daniel Alejandro Acosta Avila
#
# 21 Breiner Estiven López
#
#
# 51 Cesar Fabian Rincon Robayo

# %% [markdown]
# Modify [week_1_quadratic_Po_Shen_Loh.ipyn](https://colab.research.google.com/drive/15vXGB18_np6o0Rw8ZV4o08RTdCdDIdT0?usp=sharing) for
#
# $$ ax^3+bx^2+cx +d = 0$$
#
# using Cubic equation – Cardano–Tartaglia formula- [wikipedia](https://en.wikipedia.org/wiki/Cubic_equation)
#
# Asuume $a=1$ then work wequations are of the form
#
# $$ x^3+bx^2+cx +d = 0$$
#
# Including expalnataions. plots, solution code and test cases

# %% [markdown]
# Bulit test cases that include
#
# $$(x-1) \left( x + \frac{1}{2} + i \frac{\sqrt{3}}{2}\right) \left( x + \frac{1}{2} - i \frac{\sqrt{3}}{2}\right) =   x^3 -1 =  0  $$
#
# $$(x-1)^3 = x^3 - 3 x^2 + 3 x - 1 = 0 $$
#
# $$(x-1)(x-i)(x+i) = x^3 - x^2 + x - 1 = 0 $$
#
# $$ (x+2)^2 (x-1) = x^3 + 3 x^2 - 4 = 0  $$
# three real diferent roots,  roots in the last digits of the group members, root of mtiuplicity two, and complex roots with small and large $b$.
#
#
# **Last digits:4-9-1**

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import cmath

def cubic(b, c, d, x):
    """Calcula el valor de la ecuación cúbica, v = x**3 + bx**2 + c*x + d

    Parámetros
    ----------
    b, c, d  : float
       Coeficientes

    Returns
    -------
    v : float """

    v = x**3 + b*x**2 + c*x + d
    return v

def encontrar(r_discrim, discrim):
  if discrim >=0: # hay raices complejas
    y = r_discrim - math.sqrt(discrim)
    if y == 0:
      y = r_discrim + math.sqrt(discrim)
  else: # hay 3 raices reales
    y = complex(r_discrim-math.sqrt(abs(discrim)))
    if y ==0:
      y = r_discrim+math.sqrt(abs(discrim))
  return (y/2)**(1/3)


def solve_cubic(b, c, d):
  # Si b es grande
  if abs(b) > 1000:
    # Se busca una raíz compleja z usando numpy.roots
    z = np.roots([1, b, c, d])[0]
    # Se calculan las otras dos raíces usando la fórmula
    x1 = z
    x2 = -(b+z)
    x3 = (z**2 + b*z)/d
    return x1,x2,x3
  # Si b no es grande, se usa el método de Cardano
  else:
    r_discrim = (b**2) - (3*c)
    r_discrim_cubic = 2*(b**3) - (9*b*c) + (27*d)
    discrim = (r_discrim_cubic**2 - (4*r_discrim**3))
    var = encontrar(r_discrim_cubic, discrim)

    if r_discrim==r_discrim_cubic==0:
      x1 = -b/3
      return x1,x1,x1
    elif discrim < 0:
      #usando la formula
      theta = np.arccos(r_discrim_cubic/(2*math.sqrt(r_discrim**3)))
      x1 = -(b/3) + 2/3*math.sqrt(r_discrim)*math.cos((theta)/3)
      x2 = -(b/3) + 2/3*math.sqrt(r_discrim)*math.cos((theta +2*math.pi)/3)
      x3 = -(b/3) + 2/3*math.sqrt(r_discrim)*math.cos((theta+2*2*math.pi)/3)
      return -x1,-x2,-x3

    else:
      w = (-1 +1j*math.sqrt(3))/2
      x1 = -(1/3) *(b+var+r_discrim/var)
      x2 = -(1/3) *(b+w*var+r_discrim/(w*var))
      x3 = -(1/3) *(b+w**2*var+r_discrim/(w**2*var))
      return x1,x2,x3

# %% [markdown]
# Probando cubic para graficacion de funcion cubica
# $$x^3 - 3x^2 - 2x + 1 = 0 $$

# %%
# Test cases
b = 2
c = -3
d = -2
x = 1

result = cubic(b, c, d, x)
print(f"The value of the cubic equation at x = {x} is {result}")

# Rango de valores de x
x_values = np.linspace(-5, 5, 400)  # Crea 400 puntos en el rango de -5 a 5

# Calcula los valores de la función cúbica para los valores de x
y_values = cubic(b, c, d, x_values)

# Grafica la función cúbica
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, label=f'$x^3 + {b}x^2 + {c}x + {d}$', color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de la Ecuación Cúbica')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.show()
# Out:
# The value of the cubic equation at x = 1 is -2

# %% [markdown]
# Caso 1:
# $$  x^3 -1 =  0  $$

# %%
# Caso 1: (x-1)(x+12+sqrt(3)i)(x+12-sqrt(3)i)=x^3-1=0
b1 = -1
c1 = 1
d1 = -1
roots1 = solve_cubic(b1, c1, d1)
print("Roots of Equation 3:", roots1);

y1 = [cubic(b1, c1, d1, x) for x in x_values]
plt.figure(figsize=(8, 6))
plt.plot(x_values, y1, label='Equation 3')
plt.scatter(roots1, [0, 0, 0], color='red', label='Roots', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='r', linestyle='--', label='y = 0')
plt.legend()
plt.title('Cubic Equation 3 and Roots')
plt.grid(True)
# Out:
# Roots of Equation 3: ((-1.850371707708594e-17-1j), (0.9999999999999997-9.384709249946039e-17j), (1.1102230246251565e-16+1j))
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:192: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)

# %% [markdown]
# Caso 2:
# $$  x^3 - 3 x^2 + 3 x - 1 = 0$$

# %%
# Caso 2: (x-1)^3=x^3-3x^2+3x-1=0
b2 = -3
c2 = 3
d2 = -1
roots2 = solve_cubic(b2, c2, d2)
print("Roots of Equation 2:", roots2)

y2 = [cubic(b2, c2, d2, x) for x in x_values]
plt.figure(figsize=(8, 6))
plt.plot(x_values, y2, label='Equation 2')
plt.scatter(roots2, [0, 0, 0], color='red', label='Roots', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='r', linestyle='--', label='y = 0')
plt.legend()
plt.title('Cubic Equation 2 and Roots')
plt.grid(True)
# Out:
# Roots of Equation 2: (1.0, 1.0, 1.0)

# %% [markdown]
# Caso 3:
# $$   x^3 - x^2 + x - 1 = 0 $$

# %%
# Caso 3: (x-1)(x-i)(x+i)=x^3-x^2+x-1=0
b3 = -1
c3 = 1
d3 = -1
roots3 = solve_cubic(b3, c3, d3)
print("Roots of Equation 3:", roots3)

y3 = [cubic(b3, c3, d3, x) for x in x_values]
plt.figure(figsize=(8, 6))
plt.plot(x_values, y3, label='Equation 3')
plt.scatter(roots3, [0, 0, 0], color='red', label='Roots', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='r', linestyle='--', label='y = 0')
plt.legend()
plt.title('Cubic Equation 3 and Roots')
plt.grid(True)
# Out:
# Roots of Equation 3: ((-1.850371707708594e-17-1j), (0.9999999999999997-9.384709249946039e-17j), (1.1102230246251565e-16+1j))

# %% [markdown]
# Caso 4:
#  $$  x^3 + 3 x^2 - 4 = 0  $$

# %%
# Caso 4: (x+2)^2(x-1)=x^3+3x^2-4=0
b4 = 3
c4 = 0
d4 = -4
roots4 = solve_cubic(b4, c4, d4)
print("Roots of Equation 4:", roots4)

y4 = [cubic(b4, c4, d4, x) for x in x_values]
plt.figure(figsize=(8, 6))
plt.plot(x_values, y4, label='Equation 4')
plt.scatter(roots4, [0, 0, 0], color='red', label='Roots', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='r', linestyle='--', label='y = 0')
plt.legend()
plt.title('Cubic Equation 4 and Roots')
plt.grid(True)
# Out:
# Roots of Equation 4: ((-2-1.4802973661668753e-16j), (1-0j), (-2+0j))

# %% [markdown]
# Revisión final:
#
# REVISION DE PRECISIÓN

# %%
from numpy import allclose

variants = [
    {'b': 0.0, 'c': 0.0, 'd': -1.0},  # Caso con b igual a cero
    {'b': -3.0, 'c': 3.0, 'd': -1.0},  # Caso con b negativo
    {'b': -1.0, 'c': 1.0, 'd': -1.0},  # Caso con b y c negativos
    {'b': 3.0, 'c': 0.0, 'd': -4.0},  # Caso con b positivo y c igual a cero
    {'b': 1e-6, 'c': 1e-5, 'd': 1e-4},  # Ejemplo con b muy pequeño y positivo
    # Casos muy pequeños
    {'b': -1e-8, 'c': -1e-7, 'd': -1e-6},  # Ejemplo con b y c muy pequeños y negativos
    {'b': 1e-10, 'c': 1e-9, 'd': -1e-8},  # Ejemplo con b y c muy pequeños y positivo y d negativo
    # Casos muy grandes
    {'b': 1e6, 'c': -1e3, 'd': 1.0},  # Ejemplo con b grande y c negativo
    {'b': 1, 'c': 4, 'd': 9},  # Ejemplo con LAST DIGITS 1 - 4 - 9
]
for var in variants:
    b,c,d = var['b'], var['c'], var['d']
    eq = ""
    eq += "x^3 "
    if (b > 0):
      eq += "+ {}x^2 ".format(b)
    elif (b<0):
      eq += "{}x^2 ".format(b)
    if (c > 0):
      eq += "+ {}x ".format(c)
    elif (c<0):
      eq += "{}x ".format(c)
    if (d > 0):
      eq += "+ {}".format(d)
    elif (d<0):
      eq += "{} ".format(d)

    print(eq, end='\n')

    x1, x2, x3= solve_cubic(**var)
    #print("Roots: ", x1, x2, x3)
    print(allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3),0.0))
# Out:
# x^3 -1.0
# True
# x^3 -3.0x^2 + 3.0x -1.0
# True
# x^3 -1.0x^2 + 1.0x -1.0
# True
# x^3 + 3.0x^2 -4.0
# True
# x^3 + 1e-06x^2 + 1e-05x + 0.0001
# True
# x^3 -1e-08x^2 -1e-07x -1e-06
# True
# x^3 + 1e-10x^2 + 1e-09x -1e-08
# True
# x^3 + 1000000.0x^2 -1000.0x + 1.0
# False
# x^3 + 1x^2 + 4x + 9
# True

# %%
from numpy import allclose

vvariants = [{'b': 0.0, 'c': 0.0, 'd': -1.0},
            {'b': -3.0, 'c': 3.0,  'd':-1.0},
            {'b': -1.0, 'c': 1.0,  'd':-1.0},
            {'b':  3.0, 'c': 0.0,  'd':-4.0},
            {'b':  3.0, 'c': 0.0,  'd':-4.0},
            {'b':  1e6, 'c': 0.0,  'd':0.0},
            {'b':  1e7, 'c': 0.0,  'd':0.0},
            {'b':  1e6, 'c': 1.0,  'd':0.0},
            {'b':  1e7, 'c': 1.0,  'd':0.0},
            {'b':  1e6, 'c': -1.0,  'd':0.0},
            {'b':  1e7, 'c': -1.0,  'd':0.0},
            {'b':  -1e6, 'c': 1.0,  'd':0.0},
            {'b':  -1e7, 'c': 1.0,  'd':0.0},
            {'b':  -1e6, 'c': -1.0,  'd':0.0},
            {'b':  -1e7, 'c': -1.0,  'd':0.0},
            {'b':  1e6, 'c': 1.0,  'd':1.0},
            {'b':  1e6, 'c': 1.0,  'd':-1.0},
            {'b':  1e6, 'c': -1.0,  'd':1.0},
            {'b':  1e6, 'c': -1.0,  'd':-1.0},
            {'b':  1e7, 'c': 1.0,  'd':1.0},
            {'b':  1e7, 'c': 1.0,  'd':-1.0},
            {'b':  1e7, 'c': -1.0,  'd':1.0},
            {'b':  1e7, 'c': -1.0,  'd':-1.0},
            {'b':  1e8, 'c': 1.0,  'd':1.0},
            {'b':  1e8, 'c': 1.0,  'd':-1.0},
            {'b':  1e8, 'c': -1.0,  'd':1.0},
            {'b':  1e8, 'c': -1.0,  'd':-1.0},]

for var in variants:
    x1, x2, x3= solve_cubic(**var)
    print("var:",var)
    print("roots:",x1, x2, x3)
    print("cubic in the roots:",cubic(var['b'],var['c'],var['d'],x1), cubic(var['b'],var['c'],var['d'],x2), cubic(var['b'],var['c'],var['d'],x3))
    print("allclose 1:",allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0))
    print("allclose 2:",allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0))
    print("allclose 3:",allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
    print("allclose:",allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
# Out:
# var: {'b': 0.0, 'c': 0.0, 'd': -1.0}
# roots: (-0.5000000000000001-0.8660254037844386j) (1-7.401486830834377e-17j) (-0.5+0.8660254037844386j)
# cubic in the roots: -3.885780586188048e-16j -2.220446049250313e-16j (-2.220446049250313e-16+1.1102230246251565e-16j)
# allclose 1: True
# allclose 2: True
# allclose 3: True
# allclose: True
# var: {'b': -3.0, 'c': 3.0, 'd': -1.0}
# roots: 1.0 1.0 1.0
# cubic in the roots: 0.0 0.0 0.0
# allclose 1: True
# allclose 2: True
# allclose 3: True
# allclose: True
# var: {'b': -1.0, 'c': 1.0, 'd': -1.0}
# roots: (-1.850371707708594e-17-1j) (0.9999999999999997-9.384709249946039e-17j) (1.1102230246251565e-16+1j)
# cubic in the roots: 0j (-6.661338147750939e-16-1.8769418499892065e-16j) (-2.220446049250313e-16-2.220446049250313e-16j)
# allclose 1: True
# allclose 2: True
# allclose 3: True
# allclose: True
# var: {'b': 3.0, 'c': 0.0, 'd': -4.0}
# roots: (-2-1.4802973661668753e-16j) (1-0j) (-2+0j)
# cubic in the roots: 0j 0j 0j
# allclose 1: True
# ...

# %% [markdown]
#  Publisth the notebook in as **pperezp_groupN_CubicEquation.ipynb** at **MetNumUN2023II/Lab5** and submit only the code of **solve_cubic(b, c,d)** in UNcode Quiz Cubic Equation.
